# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# COMMON_PLAYER_INFO

# %%
archivo1 = '/Users/nicolasraimundo/Desktop/archive/csv/common_player_info.csv'

common_player_info = pd.read_csv(archivo1)

common_player_info.head()
# Out:
#    person_id first_name     last_name   display_first_last  \
# 0      76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1      76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 2       1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
# 3        949    Shareef   Abdur-Rahim  Shareef Abdur-Rahim
# 4      76005        Tom     Abernethy        Tom Abernethy
#
#   display_last_comma_first  display_fi_last          player_slug  \
# 0          Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1     Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 2       Abdul-Wahad, Tariq   T. Abdul-Wahad    tariq-abdul-wahad
# 3     Abdur-Rahim, Shareef   S. Abdur-Rahim  shareef-abdur-rahim
# 4           Abernethy, Tom     T. Abernethy        tom-abernethy
#
#              birthdate          school country  ...  \
# 0  1968-06-24 00:00:00            Duke     USA  ...
# 1  1947-04-16 00:00:00            UCLA     USA  ...
# 2  1974-11-03 00:00:00  San Jose State  France  ...
# ...

# %%
common_player_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4171 entries, 0 to 4170
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   person_id                         4171 non-null   int64
#  1   first_name                        4171 non-null   object
#  2   last_name                         4171 non-null   object
#  3   display_first_last                4171 non-null   object
#  4   display_last_comma_first          4171 non-null   object
#  5   display_fi_last                   4171 non-null   object
#  6   player_slug                       4171 non-null   object
#  7   birthdate                         4171 non-null   object
#  8   school                            4156 non-null   object
#  9   country                           4170 non-null   object
#  10  last_affiliation                  4171 non-null   object
# ...

# %%
lakers = ['Lakers']

player_filtrado = common_player_info[common_player_info['team_name'].isin(lakers)]


player_filtrado
# Out:
#       person_id first_name      last_name    display_first_last  \
# 1         76003     Kareem   Abdul-Jabbar   Kareem Abdul-Jabbar
# 98      1628961     Kostas  Antetokounmpo  Kostas Antetokounmpo
# 100        2546    Carmelo        Anthony       Carmelo Anthony
# 230       76127      Elgin         Baylor          Elgin Baylor
# 233      203145       Kent       Bazemore         Kent Bazemore
# ...         ...        ...            ...                   ...
# 3993      78564        Bob       Williams          Bob Williams
# 4020    1629140  Johnathan       Williams    Johnathan Williams
# 4115       1897      Metta    World Peace     Metta World Peace
# 4117       1460      James         Worthy          James Worthy
# 4141      78630      Wayne          Yates           Wayne Yates
#
#      display_last_comma_first   display_fi_last           player_slug  \
# 1        Abdul-Jabbar, Kareem   K. Abdul-Jabbar   kareem-abdul-jabbar
# ...

# %%
player_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163 entries, 1 to 4141
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   person_id                         163 non-null    int64
#  1   first_name                        163 non-null    object
#  2   last_name                         163 non-null    object
#  3   display_first_last                163 non-null    object
#  4   display_last_comma_first          163 non-null    object
#  5   display_fi_last                   163 non-null    object
#  6   player_slug                       163 non-null    object
#  7   birthdate                         163 non-null    object
#  8   school                            163 non-null    object
#  9   country                           163 non-null    object
#  10  last_affiliation                  163 non-null    object
#  11  height                            163 non-null    object
# ...

# %%
player_filtrado['birthdate']= pd.to_datetime(player_filtrado['birthdate'])
# Out:
# /var/folders/z_/ncwghck114sfrjgmq959t5140000gn/T/ipykernel_965/2362495702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_filtrado['birthdate']= pd.to_datetime(player_filtrado['birthdate'])

# %%
player_filtrado.head()
# Out:
#      person_id first_name      last_name    display_first_last  \
# 1        76003     Kareem   Abdul-Jabbar   Kareem Abdul-Jabbar
# 98     1628961     Kostas  Antetokounmpo  Kostas Antetokounmpo
# 100       2546    Carmelo        Anthony       Carmelo Anthony
# 230      76127      Elgin         Baylor          Elgin Baylor
# 233     203145       Kent       Bazemore         Kent Bazemore
#
#     display_last_comma_first   display_fi_last           player_slug  \
# 1       Abdul-Jabbar, Kareem   K. Abdul-Jabbar   kareem-abdul-jabbar
# 98     Antetokounmpo, Kostas  K. Antetokounmpo  kostas-antetokounmpo
# 100         Anthony, Carmelo        C. Anthony       carmelo-anthony
# 230            Baylor, Elgin         E. Baylor          elgin-baylor
# 233           Bazemore, Kent       K. Bazemore         kent-bazemore
#
#      birthdate                school country  ...  \
# 1   1947-04-16                  UCLA     USA  ...
# 98  1997-11-20  University of Dayton  Greece  ...
# ...

# %% [markdown]
# Resta modificar las columnas year de float a datetime(year). La duda de este archivo es si solamente muestra en que equipo fueron drafteados, por lo tanto no muestra la plantilla actual de los Lakers

# %%
player_filtrado.to_csv('common_player_info.csv')

# %% [markdown]
# DRAFT HISTORY

# %% [markdown]
# Draft_combine_stats tiene estadísticas de tiro, de fuerza, salto, etc... Siempre habla de las estadísticas de cada jugador para ser drafteado, por lo tanto lo descarté.

# %%
archivo2= '/Users/nicolasraimundo/Desktop/archive/csv/draft_history.csv'

draft_history = pd.read_csv(archivo2)
draft_history.head()
# Out:
#    person_id       player_name  season  round_number  round_pick  \
# 0      79299  Clifton McNeeley    1947             1           1
# 1      78109        Glen Selbo    1947             1           2
# 2      76649      Eddie Ehlers    1947             1           3
# 3      79302        Walt Dropo    1947             1           4
# 4      77048        Dick Holub    1947             1           5
#
#    overall_pick draft_type     team_id   team_city     team_name  \
# 0             1      Draft  1610610031  Pittsburgh       Ironmen
# 1             2      Draft  1610610035     Toronto       Huskies
# 2             3      Draft  1610612738      Boston       Celtics
# 3             4      Draft  1610610032  Providence  Steamrollers
# 4             5      Draft  1610612752    New York        Knicks
#
#   team_abbreviation          organization   organization_type  \
# 0               PIT         Texas-El Paso  College/University
# ...

# %%
los_angeles_lakers = ['LAL']
draft_filtrado = draft_history[draft_history['team_abbreviation'].isin(los_angeles_lakers)]

draft_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 296 entries, 1153 to 7978
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   person_id            296 non-null    int64
#  1   player_name          296 non-null    object
#  2   season               296 non-null    int64
#  3   round_number         296 non-null    int64
#  4   round_pick           296 non-null    int64
#  5   overall_pick         296 non-null    int64
#  6   draft_type           296 non-null    object
#  7   team_id              296 non-null    int64
#  8   team_city            296 non-null    object
#  9   team_name            296 non-null    object
#  10  team_abbreviation    296 non-null    object
#  11  organization         296 non-null    object
#  12  organization_type    296 non-null    object
#  13  player_profile_flag  296 non-null    int64
# dtypes: int64(7), object(7)
# memory usage: 34.7+ KB

# %%
draft_filtrado.to_csv('draft_history.csv')

# %%
archivo_c = '/Users/nicolasraimundo/Desktop/archive/csv/team_details.csv'
team_details = pd.read_csv(archivo_c)

team_details.head()
# Out:
#       team_id abbreviation   nickname  yearfounded          city  \
# 0  1610612737          ATL      Hawks       1949.0       Atlanta
# 1  1610612741          CHI      Bulls       1966.0       Chicago
# 2  1610612742          DAL  Mavericks       1980.0        Dallas
# 3  1610612743          DEN    Nuggets       1976.0        Denver
# 4  1610612744          GSW   Warriors       1946.0  Golden State
#
#                       arena  arenacapacity              owner  \
# 0          State Farm Arena        18729.0       Tony Ressler
# 1             United Center        21711.0  Michael Reinsdorf
# 2  American Airlines Center        19200.0         Mark Cuban
# 3                Ball Arena            NaN       Stan Kroenke
# 4              Chase Center            NaN          Joe Lacob
#
#        generalmanager       headcoach     dleagueaffiliation  \
# 0      Travis Schlenk     Quin Snyder  College Park Skyhawks
# 1  Arturas Karnisovas   Billy Donovan       Windy City Bulls
# ...

# %% [markdown]
# GAME. Filtré por aquellos juegos en los cuales Lakers haya sido local o visitante

# %%
game= '/Users/nicolasraimundo/Desktop/archive/csv/game.csv'

games = pd.read_csv(game)

games.head()
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
#
#     game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# 0  24600001  1946-11-01 00:00:00  HUS vs. NYK       L    0      25.0  ...
# 1  24600003  1946-11-02 00:00:00  BOM vs. PIT       W    0      20.0  ...
# 2  24600002  1946-11-02 00:00:00  PRO vs. BOS       W    0      21.0  ...
# 3  24600004  1946-11-02 00:00:00  CHS vs. NYK       W    0      21.0  ...
# 4  24600005  1946-11-02 00:00:00  DEF vs. WAS       L    0      10.0  ...
#
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65698 entries, 0 to 65697
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   season_id               65698 non-null  int64
#  1   team_id_home            65698 non-null  int64
#  2   team_abbreviation_home  65698 non-null  object
#  3   team_name_home          65698 non-null  object
#  4   game_id                 65698 non-null  int64
#  5   game_date               65698 non-null  object
#  6   matchup_home            65698 non-null  object
#  7   wl_home                 65696 non-null  object
#  8   min                     65698 non-null  int64
#  9   fgm_home                65685 non-null  float64
#  10  fga_home                50251 non-null  float64
#  11  fg_pct_home             50208 non-null  float64
#  12  fg3m_home               52480 non-null  float64
#  13  fg3a_home               47015 non-null  float64
# ...

# %%
los_angeles_lakers = ['LAL']
juegos_filtrados = games[
(games['team_abbreviation_home'].isin(los_angeles_lakers))| 
(games['team_abbreviation_away'].isin(los_angeles_lakers))
]

juegos_filtrados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5203 entries, 4852 to 65686
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   season_id               5203 non-null   int64
#  1   team_id_home            5203 non-null   int64
#  2   team_abbreviation_home  5203 non-null   object
#  3   team_name_home          5203 non-null   object
#  4   game_id                 5203 non-null   int64
#  5   game_date               5203 non-null   object
#  6   matchup_home            5203 non-null   object
#  7   wl_home                 5203 non-null   object
#  8   min                     5203 non-null   int64
#  9   fgm_home                5203 non-null   float64
#  10  fga_home                3783 non-null   float64
#  11  fg_pct_home             3783 non-null   float64
#  12  fg3m_home               3993 non-null   float64
#  13  fg3a_home               3474 non-null   float64
# ...

# %%
juegos_filtrados.sample(10)
# Out:
#        season_id  team_id_home team_abbreviation_home  \
# 8168       41970    1610612741                    CHI
# 32314      21996    1610612747                    LAL
# 12751      21978    1610612747                    LAL
# 10590      21974    1610612758                    KCK
# 17892      21983    1610612747                    LAL
# 36625      22000    1610612747                    LAL
# 8570       21971    1610612765                    DET
# 19476      21985    1610612752                    NYK
# 48787      22009    1610612747                    LAL
# 5418       21963    1610612747                    LAL
#
#                 team_name_home   game_id            game_date matchup_home  \
# 8168             Chicago Bulls  47000223  1971-03-28 00:00:00  CHI vs. LAL
# 32314       Los Angeles Lakers  29600781  1997-02-23 00:00:00  LAL vs. NYK
# 12751       Los Angeles Lakers  27800485  1979-01-19 00:00:00  LAL vs. HOU
# ...

# %%
juegos_filtrados.to_csv('games_lakers.csv')

# %% [markdown]
# GAME_SUMMARY

# %%
archivo3 ='/Users/nicolasraimundo/Desktop/archive/csv/game_summary.csv'

game_summary = pd.read_csv(archivo3)

game_summary.head()
# Out:
#          game_date_est  game_sequence   game_id  game_status_id  \
# 0  1946-11-01 00:00:00            NaN  24600001               3
# 1  1946-11-02 00:00:00            NaN  24600003               3
# 2  1946-11-02 00:00:00            NaN  24600002               3
# 3  1946-11-02 00:00:00            NaN  24600004               3
# 4  1946-11-02 00:00:00            NaN  24600005               3
#
#   game_status_text         gamecode  home_team_id  visitor_team_id  season  \
# 0              NaN  19461101/NYKHUS    1610610035       1610612752    1946
# 1              NaN  19461102/PITBOM    1610610034       1610610031    1946
# 2              NaN  19461102/BOSPRO    1610610032       1610612738    1946
# 3              NaN  19461102/NYKCHS    1610610025       1610612752    1946
# 4              NaN  19461102/WASDEF    1610610028       1610610036    1946
#
#    live_period live_pc_time natl_tv_broadcaster_abbreviation  \
# 0            5          NaN                              NaN
# ...

# %%
game_summary.info()

# %% [markdown]
# TEAM, TEAM HISTORY Y TEAM DETAILS tienen caracteristicas de cada equipo, pueden servir a futuro.

# %%
teamm = '/Users/nicolasraimundo/Desktop/archive/csv/team.csv'

team_csv = pd.read_csv(teamm)

team_csv.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta        1949.0
# 1  Massachusetts        1946.0
# 2           Ohio        1970.0
# 3      Louisiana        2002.0
# 4       Illinois        1966.0

# %% [markdown]
# Hay que modificar el tipo de dato de year_founded

# %% [markdown]
# INACTIVE PLAYERS muestra aquellos jugadores que actualmente no están jugando en la NBA. Descartado

# %%
inac = '/Users/nicolasraimundo/Desktop/archive/csv/inactive_players.csv'

nin = pd.read_csv(inac)

nin.head()
# Out:
#     game_id  player_id first_name last_name  jersey_num     team_id  \
# 0  29600034        184      Bobby    Phills        14.0  1610612739
# 1  29600034        781       Will    Perdue        41.0  1610612759
# 2  29600132        120     Steven     Smith         8.0  1610612737
# 3  29600203        698      Eddie   Johnson         8.0  1610612754
# 4  29600213         32   Clifford    Rozier        44.0  1610612753
#
#      team_city  team_name team_abbreviation
# 0    Cleveland  Cavaliers               CLE
# 1  San Antonio      Spurs               SAS
# 2      Atlanta      Hawks               ATL
# 3      Indiana     Pacers               IND
# 4      Orlando      Magic               ORL

# %% [markdown]
# LINE_SCORE

# %%
line = '/Users/nicolasraimundo/Desktop/archive/csv/line_score.csv'

line_score = pd.read_csv(line)

line_score.head()
# Out:
#          game_date_est  game_sequence   game_id  team_id_home  \
# 0  1946-11-01 00:00:00            NaN  24600001    1610610035
# 1  1946-11-02 00:00:00            NaN  24600003    1610610034
# 2  1946-11-02 00:00:00            NaN  24600002    1610612738
# 3  1946-11-02 00:00:00            NaN  24600004    1610610025
# 4  1946-11-02 00:00:00            NaN  24600005    1610610036
#
#   team_abbreviation_home team_city_name_home team_nickname_home  \
# 0                    HUS             Toronto            Huskies
# 1                    BOM           St. Louis            Bombers
# 2                    BOS              Boston            Celtics
# 3                    CHS             Chicago              Stags
# 4                    WAS          Washington           Capitols
#
#   team_wins_losses_home  pts_qtr1_home  pts_qtr2_home  ...  pts_ot2_away  \
# 0                     -            NaN            NaN  ...           NaN
# ...

# %%
line_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58053 entries, 0 to 58052
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_date_est           58053 non-null  object
#  1   game_sequence           32521 non-null  float64
#  2   game_id                 58053 non-null  int64
#  3   team_id_home            58053 non-null  int64
#  4   team_abbreviation_home  58053 non-null  object
#  5   team_city_name_home     58053 non-null  object
#  6   team_nickname_home      58053 non-null  object
#  7   team_wins_losses_home   58053 non-null  object
#  8   pts_qtr1_home           57049 non-null  float64
#  9   pts_qtr2_home           57040 non-null  float64
#  10  pts_qtr3_home           57008 non-null  float64
#  11  pts_qtr4_home           57009 non-null  float64
#  12  pts_ot1_home            32294 non-null  float64
#  13  pts_ot2_home            31002 non-null  float64
# ...

# %%
los_angeles_lakers = ['LAL']
score_filtrado = line_score[
(line_score['team_abbreviation_home'].isin(los_angeles_lakers))| 
(line_score['team_abbreviation_away'].isin(los_angeles_lakers))
]

score_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4531 entries, 4117 to 58041
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_date_est           4531 non-null   object
#  1   game_sequence           2263 non-null   float64
#  2   game_id                 4531 non-null   int64
#  3   team_id_home            4531 non-null   int64
#  4   team_abbreviation_home  4531 non-null   object
#  5   team_city_name_home     4531 non-null   object
#  6   team_nickname_home      4531 non-null   object
#  7   team_wins_losses_home   4531 non-null   object
#  8   pts_qtr1_home           4530 non-null   float64
#  9   pts_qtr2_home           4530 non-null   float64
#  10  pts_qtr3_home           4530 non-null   float64
#  11  pts_qtr4_home           4530 non-null   float64
#  12  pts_ot1_home            2254 non-null   float64
#  13  pts_ot2_home            2147 non-null   float64
# ...

# %%
score_filtrado.to_csv('line_score.csv')

# %% [markdown]
# OFFICIALS tiene información sobre arbitros de NBA. Descartado

# %% [markdown]
# PLAYER lo filtré por aquellos jugadores que están jugando

# %%
player = '/Users/nicolasraimundo/Desktop/archive/csv/player.csv'

players = pd.read_csv(player)

players.tail(15)
# Out:
#            id          full_name first_name    last_name  is_active
# 4816   202545        Luke Zeller       Luke       Zeller          0
# 4817   203092       Tyler Zeller      Tyler       Zeller          0
# 4818    78643          Tony Zeno       Tony         Zeno          0
# 4819    78644   Phil Zevenbergen       Phil  Zevenbergen          0
# 4820     1917       Wang Zhi-zhi       Wang      Zhi-zhi          0
# 4821  1627753            Zhou Qi        NaN      Zhou Qi          0
# 4822      678       George Zidek     George        Zidek          0
# 4823     2583  Derrick Zimmerman    Derrick    Zimmerman          0
# 4824  1627757  Stephen Zimmerman    Stephen    Zimmerman          0
# 4825  1627835        Paul Zipser       Paul       Zipser          0
# 4826  1627790         Ante Zizic       Ante        Zizic          0
# 4827    78647           Jim Zoet        Jim         Zoet          0
# 4828    78648          Bill Zopf       Bill         Zopf          0
# ...

# %%
players = players[players['is_active'] == 1]

players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 582 entries, 10 to 4829
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          582 non-null    int64
#  1   full_name   582 non-null    object
#  2   first_name  582 non-null    object
#  3   last_name   582 non-null    object
#  4   is_active   582 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 27.3+ KB

# %%
players.sample(10)
# Out:
#            id           full_name first_name   last_name  is_active
# 1185  1630162     Anthony Edwards    Anthony     Edwards          1
# 2106  1631300      Drake Jeffries      Drake    Jeffries          1
# 4784  1630593  McKinley Wright IV   McKinley   Wright IV          1
# 4138  1628410       Edmond Sumner     Edmond      Sumner          1
# 4130  1629622           Max Strus        Max       Strus          1
# 1116   201609        Goran Dragic      Goran      Dragic          1
# 3590  1631197        Jared Rhoden      Jared      Rhoden          1
# 178   1628963   Marvin Bagley III     Marvin  Bagley III          1
# 875    203496    Robert Covington     Robert   Covington          1
# 3660  1629010     Jerome Robinson     Jerome    Robinson          1

# %%
players.to_csv('players.csv')

# %% [markdown]
# PLAY_BY_PLAY. No trabajé este archivo, simplemente hice una vista inicial

# %%
other_stat = '/Users/nicolasraimundo/Desktop/archive/csv/play_by_play.csv'

play_by_play = pd.read_csv(other_stat)

play_by_play.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13592899 entries, 0 to 13592898
# Data columns (total 34 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   game_id                    int64
#  1   eventnum                   int64
#  2   eventmsgtype               int64
#  3   eventmsgactiontype         int64
#  4   period                     int64
#  5   wctimestring               object
#  6   pctimestring               object
#  7   homedescription            object
#  8   neutraldescription         object
#  9   visitordescription         object
#  10  score                      object
#  11  scoremargin                object
#  12  person1type                float64
#  13  player1_id                 int64
#  14  player1_name               object
#  15  player1_team_id            float64
#  16  player1_team_city          object
#  17  player1_team_nickname      object
#  18  player1_team_abbreviation  object
# ...

# %%
play_by_play.head()
# Out:
#     game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 0  29600012         0            12                   0       1     14:43 PM
# 1  29600012         2            10                   0       1     14:50 PM
# 2  29600012         3             2                   1       1     14:51 PM
# 3  29600012         4             4                   0       1     14:51 PM
# 4  29600012         5             2                   1       1     14:51 PM
#
#   pctimestring                              homedescription  \
# 0        12:00                                          NaN
# 1        12:00  Jump Ball O'Neal vs. Kleine: Tip to Cassell
# 2        11:45                                          NaN
# 3        11:43                 O'Neal REBOUND (Off:0 Def:1)
# 4        11:29              MISS Ceballos 26' 3PT Jump Shot
#
#                    neutraldescription          visitordescription  ...  \
# ...

# %% [markdown]
# ### CSV QUE SIRVEN :
# COMMON PLAYER INFO, DRAFT HISTORY, GAME(FILTRADO COMO GAMES
# _LAKERS), GAME_SUMMARY, LINE SCORE, OTHER STATS(TIENE UN SOLO PARTIDO DE LAKERS, SON 5 FILAS),PLAY BY PLAY(NO LO FILTRE),PLAYERS, Y LOS 3 CSV DE TEAM PUEDEN SER REDUCIDOS A UN ÚNICO CSV
